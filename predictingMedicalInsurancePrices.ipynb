# %% [markdown]
# <b>1  |Business objective</b>
#
# This analysis focuses on a health insurance company's data, aiming to forecast future insurance claim amounts and identify key factors contributing to elevated healthcare expenditures. The dataset, comprising 1,338 policyholders, includes seven descriptive attributes such as age, gender, BMI, and smoking status. The primary target variable for prediction is charges, representing the total claim amount submitted to the insurance provider. To enhance the precision of cost predictions, individual models will be developed for each of the four distinct policyholder regions: Southwest, Southeast, Northwest, and Northeast.

# %% [markdown]
# <b>2 | Data Overview</b>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import plot, iplot, init_notebook_mode
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import r2_score, mean_squared_error
import warnings
warnings.filterwarnings("ignore")

ins = pd.read_csv("/home/dean/git/ML_Data_projects/MedicalCost/archive/insurance.csv")
print("There are {:,} observations and {} columns in the data set.".format(ins.shape[0], ins.shape[1]))
print("There are {} missing values in the data.".format(ins.isna().sum().sum()))
ins['sex'] = ins['sex'].str.capitalize()
ins['smoker'] = ins['smoker'].apply(lambda x: 'Smoker' if x=='yes' else 'Non-Smoker')
ins['region'] = ins['region'].str.capitalize()
# Out:
# There are 1,338 observations and 7 columns in the data set.
# There are 0 missing values in the data.

# %% [markdown]
# <b>2.1 | Summary Statistics of Numeric Columns</b>

# %%
ins.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %% [markdown]
# <b>2.2| Summary Statistics of Categorical Columns</b>

# %%
ins.select_dtypes(include=['object']).describe()
# Out:
#          sex      smoker     region
# count   1338        1338       1338
# unique     2           2          4
# top     Male  Non-Smoker  Southeast
# freq     676        1064        364

# %%
cat=ins.select_dtypes(include=['object']).columns.tolist()
for i in cat:
    obs=ins[i].value_counts()
    avg_claim=ins.groupby(i)["charges"].mean()
    display(pd.DataFrame({"Number of Policyholders":obs, "Average Claim Amount":avg_claim.map('${:,.2f}'.format)})\
            .sort_values('Number of Policyholders', ascending=False)\
            .style.set_caption("Variable: {}".format(i)))
# Out:
# <style type="text/css">
# </style>
# <table id="T_3f62e">
#   <caption>Variable: sex</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f62e_level0_col0" class="col_heading level0 col0" >Number of Policyholders</th>
#       <th id="T_3f62e_level0_col1" class="col_heading level0 col1" >Average Claim Amount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f62e_level0_row0" class="row_heading level0 row0" >Male</th>
#       <td id="T_3f62e_row0_col0" class="data row0 col0" >676</td>
#       <td id="T_3f62e_row0_col1" class="data row0 col1" >$13,956.75</td>
#     </tr>
#     <tr>
#       <th id="T_3f62e_level0_row1" class="row_heading level0 row1" >Female</th>
#       <td id="T_3f62e_row1_col0" class="data row1 col0" >662</td>
#       <td id="T_3f62e_row1_col1" class="data row1 col1" >$12,569.58</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_1d11a">
#   <caption>Variable: smoker</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d11a_level0_col0" class="col_heading level0 col0" >Number of Policyholders</th>
#       <th id="T_1d11a_level0_col1" class="col_heading level0 col1" >Average Claim Amount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >smoker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d11a_level0_row0" class="row_heading level0 row0" >Non-Smoker</th>
#       <td id="T_1d11a_row0_col0" class="data row0 col0" >1064</td>
#       <td id="T_1d11a_row0_col1" class="data row0 col1" >$8,434.27</td>
#     </tr>
#     <tr>
#       <th id="T_1d11a_level0_row1" class="row_heading level0 row1" >Smoker</th>
#       <td id="T_1d11a_row1_col0" class="data row1 col0" >274</td>
#       <td id="T_1d11a_row1_col1" class="data row1 col1" >$32,050.23</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_294b4">
#   <caption>Variable: region</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_294b4_level0_col0" class="col_heading level0 col0" >Number of Policyholders</th>
#       <th id="T_294b4_level0_col1" class="col_heading level0 col1" >Average Claim Amount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_294b4_level0_row0" class="row_heading level0 row0" >Southeast</th>
#       <td id="T_294b4_row0_col0" class="data row0 col0" >364</td>
#       <td id="T_294b4_row0_col1" class="data row0 col1" >$14,735.41</td>
#     </tr>
#     <tr>
#       <th id="T_294b4_level0_row1" class="row_heading level0 row1" >Northwest</th>
#       <td id="T_294b4_row1_col0" class="data row1 col0" >325</td>
#       <td id="T_294b4_row1_col1" class="data row1 col1" >$12,417.58</td>
#     </tr>
#     <tr>
#       <th id="T_294b4_level0_row2" class="row_heading level0 row2" >Southwest</th>
#       <td id="T_294b4_row2_col0" class="data row2 col0" >325</td>
#       <td id="T_294b4_row2_col1" class="data row2 col1" >$12,346.94</td>
#     </tr>
#     <tr>
#       <th id="T_294b4_level0_row3" class="row_heading level0 row3" >Northeast</th>
#       <td id="T_294b4_row3_col0" class="data row3 col0" >324</td>
#       <td id="T_294b4_row3_col1" class="data row3 col1" >$13,406.38</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <b>3 | Exploratory Data Analysis</b>

# %%
init_notebook_mode(connected=True)
px.defaults.template = "plotly_white"
plot_df=ins.copy()
fig = px.box(plot_df, x="region", y="charges", color="region", 
             notched=True, points="outliers", height=600,
             title="Distribution of Insurance Costs by Region",
             color_discrete_sequence=["#4EB14B", "#421B0E", "#2D12C7", "#DD0505"])
fig.update_traces(marker=dict(size=9, opacity=0.5, line=dict(width=1,color="#F7F7F7")), showlegend=False)
fig.update_layout(font_color="#6B1A1A", xaxis_title='Region', yaxis_title='Claim Amount, $',
                  yaxis=dict(showgrid=True, gridwidth=1, gridcolor='#EAEAEA', zerolinecolor='#EAEAEA'))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="82940c86-94b2-4c97-afcb-0506037bfca5" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("82940c86-94b2-4c97-afcb-0506037bfca5")) {                    Plotly.newPlot(                        "82940c86-94b2-4c97-afcb-0506037bfca5",                        [{"alignmentgroup":"True","boxpoints":"outliers","hovertemplate":"region=%{x}\u003cbr\u003echarges=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Southwest","marker":{"color":"#4EB14B","line":{"color":"#F7F7F7","width":1},"opacity":0.5,"size":9},"name":"Southwest","notched":true,"offsetgroup":"Southwest","orientation":"v","showlegend":false,"x":["Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest","Southwest", ...

# %% [markdown]
# Across all regions, the boxplots reveal that insurance charges are positively skewed and include numerous large outliers. The Southeast region exhibits the most variability in charges, encompassing both the highest claim in the dataset (over $63,000) and the lowest ($1,121). While the Northeast region has the highest median cost, the overlapping notches in the boxplots suggest these median claim amounts are likely not statistically different.

# %%
fig=px.histogram(ins, x='charges', color='smoker', opacity=0.7, barmode='overlay',
                 histnorm='probability density', marginal='box', 
                 title="Distribution of Insurance Costs by Smoking Status",
                 color_discrete_sequence=['#B14B51','#B7A294']) 
fig.update_layout(font_color="#303030", xaxis_title='Claim Amount, $',
                  yaxis=dict(title='Probability Density', gridcolor='#EAEAEA', zerolinecolor='#EAEAEA'),
                  legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1, title=""))
fig.update_xaxes(showgrid=False, zerolinecolor='#EAEAEA')
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="84838333-6018-45c4-a7a3-bebf1ead159e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("84838333-6018-45c4-a7a3-bebf1ead159e")) {                    Plotly.newPlot(                        "84838333-6018-45c4-a7a3-bebf1ead159e",                        [{"bingroup":"x","histnorm":"probability density","hovertemplate":"smoker=Smoker\u003cbr\u003echarges=%{x}\u003cbr\u003eprobability density=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Smoker","marker":{"color":"#B14B51","opacity":0.7,"pattern":{"shape":""}},"name":"Smoker","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":
lGUgVdFA\u002fKnx0s3U0UCJQWDlEPLXQAisHFr0stRAaJHtfK\u002fh0UBX7C+7IXzRQERpb\u002fAV8eJAsHJokVPa1kAC2evd7OvqQOJYF7e7ZOVABFYOLWhJ1EBeS8gHrVXjQDcawFugluFAIR\u002f0bHrj2kBqvHSTHvrlQOVhodbEMuJANe84RfWP5EB+HThnuorXQGRd3EbFAeRA1edqK\u002f7kzkAIrBxaMITmQJqZmZnjleZAIv32dexB00CLbOf7m5TaQET67eu+pNxAFYxK6lSV5UCASL99g1XTQKCJsOExxOdAJQaBlRMW0UBFR3L5lXjgQJoIG56UQ9VA9l0R\u002fKsf4UDsUbge6RDjQGQ7309dd9NAVOOlm9ws50D0\u002fdR40QrjQMe6uI1oitNAPQrXo\u002fCB5EDrc7UVRwnkQK8l5IPYZ9dA9bnaimGFz0Db+X5q\u002fL\u002fSQKMBvAXydcxADwu1ph8J0EBeS8gHcfTQQP7UeOka1eBA1QloIs5U2ECRD3o271PSQOY\\u002fIan940CJ0t7gV2XjQLMMcayrxtBAZmZmZqbz1UDEQq1p6lPXQOC+DpyX5dJAS8gHPQ\u002fm0UAAAAAAK0viQFtCPujVQtVAVFInoHFD4ED99nXg3MvRQEoMAivvweJA78nDQjfS00AGgZVDs1fkQJWCbi9rg9lAw7tcxKxO7UAe+YOB1bHTQNnO91O7FOdAHHxhMjU16EBDHOvi8FziQC7\u002fIf0aNtJA2\u002fl+amy0z0BE+u3roEvaQCgPC7XBueBAt2J\u002f2dWk0EDNzMzMgu\u002fVQCgPC7Xs9ddA5IOezbrly0CPwvUofCXnQDEIrBwSueJAc2iR7ZQB4UCPcFrwG5DuQ ...

# %% [markdown]
# Comparing insurance claims, non-smokers have a much lower median claim of roughly $7,300 compared to smokers, whose median claim exceeds $34,000. The distributions of these costs also differ considerably. Non-smoker claims are right-skewed, while smoker claims exhibit more variability (a wider boxplot spread) and a bimodal pattern with noticeable peaks near $20,000 and $40,000.

# %%
plot_df = ins.copy()
plot_df["Age_Group"]=['18 to 29 years' if i<30 else '30 to 44 years' if (i>=30)&(i<45) else 
                      '45 to 59 years' if (i>=45)&(i<60) else '60 and over' for i in ins['age']]
plot_df = plot_df.groupby(['Age_Group','smoker'])['charges'].mean()
plot_df = plot_df.rename('charges').reset_index().sort_values('smoker', ascending=True)
fig = px.bar(plot_df, x='Age_Group', y='charges', color='smoker', height=500, text='charges', 
             opacity=0.75, barmode='group', color_discrete_sequence=['#B7A294','#B14B51'],
             title="Average Insurance Costs by Age and Smoking Status")
fig.update_traces(texttemplate='$%{text:,.0f}', textposition='outside', 
                  marker_line=dict(width=1, color='#303030'))
fig.update_layout(font_color="#303030",bargroupgap=0.05, bargap=0.3, 
                  legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1, title=""),
                  xaxis=dict(title='Age',showgrid=False), 
                  yaxis=dict(title='Claim Amount, $', showgrid=False,zerolinecolor='#DBDBDB',
                             showline=True, linecolor='#DBDBDB', linewidth=2))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="c96f93cf-4a89-4aba-b5cc-e46e9637766b" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c96f93cf-4a89-4aba-b5cc-e46e9637766b")) {                    Plotly.newPlot(                        "c96f93cf-4a89-4aba-b5cc-e46e9637766b",                        [{"alignmentgroup":"True","hovertemplate":"smoker=Non-Smoker\u003cbr\u003eAge_Group=%{x}\u003cbr\u003echarges=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Non-Smoker","marker":{"color":"#B7A294","opacity":0.75,"pattern":{"shape":""},"line":{"color":"#303030","width":1}},"name":"Non-Smoker","offsetgroup":"Non-Smoker","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"xmBmepFCsUB70U3nVCG7QFicAETVL8dA6Kw70FrAzUA="},"textposition":"outside","x":["18 to 29 years","30 to 44 years","45 to 59 years","60 and over"],"xaxis":"x","y":{"dtype":"f8","bdata":"xmBmepFCsUB70U3nVCG7QFicAETVL8dA6Kw70FrAzUA="},"yaxis":"y","type":"bar","texttemplate":"$%{text:,.0f}"},{"alignmentgroup":"True","hovertemplate":"smoker=Smoker\u003cbr\u003eAge_Group=%{x}\u003cbr\u003echarges=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Smoker","marker":{"color":"#B14B51","opacity":0.75,"pattern":{"shape":""},"line":{"color":"#303030","width":1}},"name":"Smoker","offsetgroup":"Smoker","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"X\u002fa6QYLf2kCwkQE3fxzeQAYQf887huFAJ+D\u002fPtbW40A="},"textposition":"outside","x":["18 to 29 years","30 to 44 years","45 to 59 years","60 and over"],"xaxis":"x","y":{"dtype":"f8","bdata":"X\u002fa6QYLf2kCwkQE3fxzeQAYQf887huFAJ+D\u002fPtbW40A="},"yaxis":"y","type":"bar","texttemplate":"$%{text:,.0f}"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewid ...

# %% [markdown]
# Within every age group, smokers consistently incur significantly higher insurance charges than non-smokers. Additionally, claim amounts generally increase with age, with the most expensive claims observed in the 60 and over age group.

# %%
fig = px.scatter(ins, x='bmi', y='charges', color='smoker', size='charges',
                 title="Insurance costs increase with Body Mass Index among Smokers",
                 color_discrete_sequence=['#B14B51','#B7A294'],height=600)
fig.update_layout(legend=dict(title='',orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1),
                  font_color="#303030", xaxis=dict(title='Body Mass Index (BMI)',showgrid=False), 
                  yaxis=dict(title='Claim Amount, $',showgrid=False, zerolinecolor='#E5E5EA',
                             showline=True, linecolor='#E5E5EA', linewidth=2))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="fbbec819-12c7-45dc-9080-8856f864f629" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fbbec819-12c7-45dc-9080-8856f864f629")) {                    Plotly.newPlot(                        "fbbec819-12c7-45dc-9080-8856f864f629",                        [{"hovertemplate":"smoker=Smoker\u003cbr\u003ebmi=%{x}\u003cbr\u003echarges=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Smoker","marker":{"color":"#B14B51","size":{"dtype":"f8","bdata":"YOXQIjt90ECV1AloLijbQAYSFD94V+NA5\u002fup8a784UCk374OvGjiQAAAAADg5uJAUI2XbjJg4UC8kXnkUf\u002foQPwYc9fIa+NAO99PjauF50CDwMqhpebiQCGwcmgRBNdACmgibNJt4kBwzojSDzHnQH3Qs1nlv+BAUwWjkjKz1kBiodY037vMQAWjkjrJP9FAz\u002fdT43Ew0EBjf9k9pSXiQFTjpZuQc+NAliGOdaOa1EC8lpAPXkflQIqO5PI7et1AKVyPwmEX50DdJAaBKePVQPT91HhZ5s5A2IFzRow33kCq8dJNGCbRQEaU9gbx+eZA\u002fmX35PGo0kD8qfHSj1DjQOxRuB5FrtBA0NVW7Iv330DhehSuH4fSQB4Wak1\u002fQtRAD5wzohHi40BAE2HDL3\u002fTQKmkTkDrudRAjZduEhdPzkAc6+I2yAriQL6fGi8t2dRA9P3UeK+m4UBmZmZmDtfnQ
Drc7UVRwnkQK8l5IPYZ9dA9bnaimGFz0Db+X5q\u002fL\u002fSQKMBvAXydcxADwu1ph8J0EBeS8gHcfTQQP7UeOka1eBA1QloIs5U2ECRD3o271PSQOY\\u002fIan940CJ0t7gV2XjQLMMcayrxtBAZmZmZqbz1UDEQq1p6lPXQOC+DpyX5dJAS8gHPQ\u002fm0UAAAAAAK0viQFtCPujVQtVAVFInoHFD4ED99nXg3MvRQEoMAivvweJA78nDQjfS00AGgZVDs1fkQJWCbi9rg9lAw7tcxKxO7UAe+YOB1bHTQNnO91O7FOdAHHxhMjU16EBDHOvi8FziQC7\u002fIf0aNtJA2\u002fl+amy0z0BE+u3roEvaQCgPC7XBueBAt2J\u002f2dWk0EDNzMzMgu\u002fVQCgPC7Xs9ddA5IOezbrly0CPwvUofCXnQDEIrBwSueJAc2iR7ZQB4UCPcFrwG5DuQGIQWDnFz+ZAeHqlLLd44kBhMlUw2MLUQNEi2\u002fmmec9AVcGopB741ECJQWDllI3gQFCNl26yxeFA0m9fB3hT0kB88rBQVXHbQDBMpgoMb+VAMLsnD1d13EA="},"sizemode":"ar ...

# %% [markdown]
# Besides age, BMI is also positively correlated with claim amounts. For smokers specifically, insurance charges tend to rise with increasing BMI.

# %%
plot_df = ins.groupby(['region','sex','smoker'])['charges'].mean()
plot_df = plot_df.rename('charges').reset_index()
fig = px.bar(plot_df, x='region', y='charges', color='sex', height=800,
             title="Average Insurance Costs by Region and Smoking Status",
             color_discrete_map={'Female': '#BFC5DA','Male': '#5D6A92'}, 
             facet_row='smoker', text='charges', opacity=0.85, barmode='group')
fig.update_traces(texttemplate='$%{text:,.0f}', textposition='outside', 
                  marker_line=dict(width=1, color='#303030'))
fig.layout.yaxis2.update(matches=None)
fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig.update_xaxes(title="Region", row=1)
fig.update_yaxes(title="Claim Amount, $",  gridcolor='#E3E3E3', zeroline=True, zerolinewidth=2, 
                 showgrid=False, zerolinecolor='#E5E5EA',
                 showline=True, linecolor='#E5E5EA', linewidth=2)
fig.update_layout(font_color="#303030", paper_bgcolor="white", plot_bgcolor="white",
                  bargroupgap=0.05, bargap=0.2,
                  legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1, title=""))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="277c834d-1652-4755-97ca-90f90ed4354f" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("277c834d-1652-4755-97ca-90f90ed4354f")) {                    Plotly.newPlot(                        "277c834d-1652-4755-97ca-90f90ed4354f",                        [{"alignmentgroup":"True","hovertemplate":"sex=Female\u003cbr\u003esmoker=Non-Smoker\u003cbr\u003eregion=%{x}\u003cbr\u003echarges=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female","marker":{"color":"#BFC5DA","opacity":0.85,"pattern":{"shape":""},"line":{"color":"#303030","width":1}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"GaZlpzbUwkBG2rPUfynBQDirhk8afMBAU45prgsVwEA="},"textposition":"outside","x":["Northeast","Northwest","Southeast","Southwest"],"xaxis":"x2","y":{"dtype":"f8","bdata":"GaZlpzbUwkBG2rPUfynBQDirhk8afMBAU45prgsVwEA="},"yaxis":"y2","type":"bar","texttemplate":"$%{text:,.0f}"},{"alignmentgroup":"True","hovertemplate":"sex=Female\u003cbr\u003esmoker=Smoker\u003cbr\u003eregion=%{x}\u003cbr\u003echarges=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female","marker":{"color":"#BFC5DA","opacity":0.85,"pattern":{"shape":""},"line":{"color":"#303030","width":1}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"2JQt+AJg20BiSOjLtPncQDIET0NaIeBAGOdvQv\u002fx3kA="},"textposition":"outside","x":["Northeast","Northwest","Southeast","Southwest"],"xaxis":"x","y":{"dtype":"f8","bdata":"2JQt+AJg20BiSOjLtPncQDIET0NaIeBAGOdvQv\u002fx3kA="},"yaxis":"y","type":"bar","texttemplate":"$%{text:,.0f}"},{"alignmentgroup":"True","hovertemplate":"sex=Male\u003cbr\u003esmoker=Non-Smoker\u003cbr\u003eregion=%{x}\u003cbr\u003echarges=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male","marker":{"color":"#5D6A92","opacity":0.85,"pattern":{"shape":""},"line":{"color":"#303030","width":1}},"name":"Male","offsetgroup":"Male","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"lCmLZwXswEAfn6k7WEDAQLcdD+sAub1ArvkW0edivkA="},"textposition":"outside","x":["Northeast","Northwest","Southeast","Southwest"],"xaxis":"x2","y":{"dtype":"f8","bdata":"lCmLZwXswEAfn6k7WEDAQLcdD+sAub1ArvkW0edivkA="},"yaxis":"y2","type":"bar","texttemplate":"$%{text:,.0f}"},{"alignmentgroup":"True","hovertemplate":"sex=Male\u003cbr\u003esmoker=Smoker\u003cbr\u003eregion=%{x}\u003cbr\u003echarges=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male","marker":{"color":"#5D6A92","opacity":0.85,"pattern":{"shape":""},"line":{"color":"#303030","width":1}},"name":"Male","offsetgroup":"Male","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"G3JRKpAz3kAzvV+cS\u002f7dQMM6F9y6l+FA2DUAObfV30A="},"textposition":"outside","x":["Northeast","Northwest","Southeast","Southwest"],"xaxis":"x","y":{"dtype":"f8","bdata":"G3JRKpAz3kAzvV+cS\u002f7dQMM6F9y6l+FA2DUAObfV30A="},"yaxis":"y","type":"bar","texttemplate":"$%{text:,.0f}"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"}, ...

# %% [markdown]
# A clear disparity exists in insurance claims across all regions: non-smokers consistently face average costs below $10,000, while smokers' claims typically range from $28,000 to over $36,000. The data also reveals subtle gender-based differences: non-smoking women generally incur slightly higher average costs than non-smoking men, whereas among smokers, men tend to have slightly higher average charges than women.

# %%
ins = pd.read_csv("/home/dean/git/ML_Data_projects/MedicalCost/archive/insurance.csv")
ins['sex'] = ins['sex'].str.capitalize()
ins['smoker'] = ins['smoker'].apply(lambda x: 'Smoker' if x=='yes' else 'Non-Smoker')
ins['region'] = ins['region'].str.capitalize()

ins['female'] = ins['sex'].apply(lambda x: 1 if x=='Female' else 0)
ins['smoker_yes'] = ins['smoker'].apply(lambda x: 1 if x=='Smoker' else 0)
ins.drop(['sex', 'smoker'], axis=1, inplace=True)
ins_for_corr = ins.drop('region', axis=1).copy()

sns.set_context("notebook")
fig, ax = plt.subplots(figsize=(9,6))   
corr=ins_for_corr.corr()
mask=np.triu(np.ones_like(corr, dtype=bool))[1:, :-1]
corr=corr.iloc[1:,:-1].copy()
ax=sns.heatmap(corr, mask=mask, vmin=-.1, vmax=.9, center=0, annot=True, fmt='.2f', 
               cmap='ocean', linewidths=4, annot_kws={"fontsize":12})
ax.set_title('\nCorrelations of Health Insurance Costs\n', fontsize=18)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right',fontsize=12)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=12)
fig.show()

# %% [markdown]
# While a significant positive correlation (0.79) exists between smoking and insurance charges, the dataset's remaining variables generally show limited inter-correlations.

# %% [markdown]
# <b>4 | Methodology</b>
#
# To capture complex relationships, such as that between smoking status and BMI, interaction terms and second-order polynomial features will be added to the models, incorporating squared terms for each variable and interaction terms for each feature pair.
#
# Given the relatively balanced distribution of beneficiaries across the four regions (324-364 per region), separate predictive models will be developed for each region to enable more targeted cost predictions. This involves filtering data by region before creating individual training and test sets. I will employ various regression models—Linear Regression, K-Nearest Neighbors, Support Vector Machines, and Gradient Boosting—to forecast future insurance costs. Model performance will be optimized through hyperparameter tuning via cross-validation, followed by evaluation on the dedicated test sets.

# %% [markdown]
# <b>5 |</b> Linear Regression with PCA Dimensionality Reduction</b>
#
#
# With the addition of polynomial features, the number of variables in the dataset increases from 5 to 20. Due to the effects of multicollinearity, I will use Principal Component Analysis (PCA) to reduce the correlation between the features in the linear regression models. Principal Component Analysis is a technique that reduces the dimensionality of a data set by transforming variables that are potentially correlated into linearly uncorrelated principal components.

# %%
models=["Linear Regression", "KNN", "SVM", "Gradient Boosting"]
mod_res=pd.DataFrame(columns=["Average RMSE", "Avg. Adjusted R2"], index=models)
regions = ins.region.unique()
s = StandardScaler()

actuals=[]
preds=[]
rmses=[]
r2_scores=[]
adj_r2_scores=[]

for i in regions:
    
    # Filter data by region
    print("\nRegion: {}\n".format(i))
    ins_df = ins[ins.region==i]
    X=ins_df.drop(['charges', 'region'], axis=1)
    y=ins_df.charges
    
    # Add polynomial features
    pf = PolynomialFeatures(degree=2, include_bias=False)
    X_pf = pd.DataFrame(data=pf.fit_transform(X), columns=pf.get_feature_names_out(X.columns))
    
    # Create training and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_pf, y, test_size=0.2, random_state=1)
    
    # Scale features
    X_train_scaled = s.fit_transform(X_train)
    X_test_scaled = s.transform(X_test)
    
    # PCA
    pca = PCA(.95)
    X_train_pca=pca.fit_transform(X_train_scaled)
    X_test_pca=pca.transform(X_test_scaled)
    print("Number of Principal Components = {}".format(pca.n_components_))
    print("Train Shape:{} {}  Test Shape:{} {}".format(X_train_pca.shape, y_train.shape, X_test_pca.shape, y_test.shape))
    
    # Linear Regression
    lr = LinearRegression().fit(X_train_pca, y_train)
    y_pred=lr.predict(X_test_pca)
    rmse=np.sqrt(mean_squared_error(y_test, y_pred)).round(2)
    r2=r2_score(y_test, y_pred)
    adj_r2 = 1 - (1-r2)*(len(y_test)-1)/(len(y_test)-X_test_pca.shape[1]-1)
    
    actuals.append(pd.Series(y_test, name='actuals').reset_index())
    preds.append(pd.Series(y_pred, name='preds').reset_index(drop=True))
    rmses.append(rmse)
    r2_scores.append(r2)
    adj_r2_scores.append(adj_r2)
    
    print("Test Error (RMSE) = {:,}".format(rmse))
    print("R-Squared = {:.2f}%, Adjusted R-Squared = {:.2f}%".format(r2*100, adj_r2*100))
    if i != 'Northeast':
        print("__________________________")

# Plot results
for i in range(0,4):
    actuals[i].loc[:,'index']=regions[i]
actual = pd.concat([actuals[i] for i in range(4)], axis = 0)
pred = pd.concat([preds[i] for i in range(4)], axis = 0)
df = pd.concat([actual, pred], axis=1).reset_index(drop=True)
col = ["#B14B51", '#D0A99C', '#5D8370','#6C839B']
fig = px.scatter(df, x="actuals", y="preds", color="index", trendline="ols", height=700,
                 title="Actual vs Predicted Insurance Costs by Region,<br>Linear Regression with Principal Component Analysis",
                 color_discrete_sequence=col, opacity=0.7, facet_col='index', facet_col_wrap=2)

fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[0]*100,rmses[0]),
                   x=51e3,y=15e3, row=2,col=1, showarrow=False)
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[1]*100,rmses[1]),
                   x=51e3,y=15e3, row=2,col=2, showarrow=False)
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[2]*100,rmses[2]),
                   x=51e3,y=15e3, row=1,col=1, showarrow=False)
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[3]*100,rmses[3]),
                   x=51e3,y=15e3, row=1,col=2, showarrow=False)

fig.update_traces(hovertemplate="Actual Cost: %{x:$,.2f}<br>Predicted Cost: %{y:$,.2f}",
                  marker=dict(size=10, line=dict(width=1,color="#F7F7F7")),
                  selector=dict(mode="markers"), showlegend=False)
fig.update_xaxes(title="Actual Cost, $", row=1)
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#EAEAEA',
                 zeroline=True, zerolinewidth=2, zerolinecolor='#5E5E5E')
fig.update_yaxes(title="Predicted Cost, $", col=1)
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#E3E3E3',
                 zeroline=True, zerolinewidth=2, zerolinecolor='#5E5E5E')
fig.update_layout(font_color="#303030", paper_bgcolor="white", plot_bgcolor="white")
fig.show()
# Out:
# Region: Southwest
#
# Number of Principal Components = 7
# Train Shape:(260, 7) (260,)  Test Shape:(65, 7) (65,)
# Test Error (RMSE) = 5,349.04
# R-Squared = 79.15%, Adjusted R-Squared = 76.59%
# __________________________
#
# Region: Southeast
#
# Number of Principal Components = 7
# Train Shape:(291, 7) (291,)  Test Shape:(73, 7) (73,)
# Test Error (RMSE) = 4,699.59
# R-Squared = 90.32%, Adjusted R-Squared = 89.27%
# __________________________
#
# Region: Northwest
#
# Number of Principal Components = 6
# Train Shape:(260, 6) (260,)  Test Shape:(65, 6) (65,)
# Test Error (RMSE) = 6,305.7
# R-Squared = 74.43%, Adjusted R-Squared = 71.79%
# __________________________
#
# Region: Northeast
#
# Number of Principal Components = 7
# Train Shape:(259, 7) (259,)  Test Shape:(65, 7) (65,)
# Test Error (RMSE) = 6,231.75
# R-Squared = 63.27%, Adjusted R-Squared = 58.76%
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="4eb4e2e8-aa43-4bb0-be1b-0209a94f0afc" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4eb4e2e8-aa43-4bb0-be1b-0209a94f0afc")) {                    Plotly.newPlot(                        "4eb4e2e8-aa43-4bb0-be1b-0209a94f0afc",                        [{"hovertemplate":"Actual Cost: %{x:$,.2f}\u003cbr\u003ePredicted Cost: %{y:$,.2f}","legendgroup":"Southwest","marker":{"color":"#B14B51","opacity":0.7,"symbol":"circle","line":{"color":"#F7F7F7","width":1},"size":10},"mode":"markers","name":"Southwest","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"3SQGgZVirUA9CtejEM3GQMuhRbbzp7hAF9nO94P3y0DLoUW2c5DGQGq8dJMY2LNAg8DKoYUmwEBg5dAi29qsQOf7qfGu\u002fOFAEFg5tFjUyUC6SQwCo8LWQKG+ZU4EK+FAdZMYBJYdyECgGi\u002fdtKjDQI2XbhJDcLVAAAAAAODm4kCiRbbz3Ry8QAaBlUOLq7lAYOXQIrtbt0BzaJHtlAHhQNv5fmpcyLlAVOOlm5Bz40AEVg4tMqGTQNejcD0KaZNAYhBYOVSaskB1kxgEZhjCQEjhehRuT8pAMQisHFp9m0D2KFyPQmaTQDvfT42rhedA2\u002fl+amy0z0Dwp8ZLX7fYQBSuR+H6E8VAuB6F6xGPskC8dJMYdLbAQEJg5dAa7eRA5\u002fup8cIqwEA9CtejEJzGQFTjpZuEx71ANV66SXy5x0CGIAclkiXUQKrx0k3CJrJAMLsnDxeH2UDhehSux1+fQCcxCKw8fsBA7F
A=="},"xaxis":"x3","y":{"dtype":"f8","bdata":"R5MT+pEHq0D4bmEluAirQIaR7FzuH6tADG9btx8pq0CMA31t\u002fESuQC258SalX65AMMwLjlGzr0DJAJfJr\u002fqvQJyRRdq2brVA+CNoFNGmtUAQAl4yLGK2QAEFuanSgrhAeLpiQg7ZuEBdlIwHXeK4QGBDltkO6blAm4McCXw6u0CcOqDXxtC8QB5YRZlr471A3AwCswW6vkDZKghQ2NG+QMbQ2zmutb9Aujs ...

# %% [markdown]
# <b>5.1</span> | Model Summary</b>

# %%
mod_res.iloc[0,0]=pd.Series(rmses).mean()
mod_res.iloc[0,1]=pd.Series(adj_r2_scores).mean()
display(mod_res.iloc[:1,].sort_values("Average RMSE"))
# Out:
#                   Average RMSE Avg. Adjusted R2
# Linear Regression      5646.52         0.741028

# %% [markdown]
# Among the four models evaluated, linear regression achieved its strongest performance in the Southeast, boasting an adjusted
# $R^2$ of 89.3% and an RMSE of approximately $4,700. This indicates the model accounts for nearly 89% of cost variation in this region, with predictions typically within $4,700 of actual median claims.
#
# All models utilized 7 principal components, except for the Northwest region's model, which used only 6. While the Northwest model explains over 70% of cost variance, it concurrently yielded the highest test error across all regions.
#
# Across all regions, the linear models' test RMSE ranged from a low of $4,700 (Southeast) to a high of about $6,300 (Northwest), with an average adjusted
# $R^2$ of 74.1%.

# %% [markdown]
# <b>6 | K-Nearest Neighbors</b>

# %%
actuals=[]
preds=[]
rmses=[]
r2_scores=[]
adj_r2_scores=[]

for i in regions:
    
    # Filter data by region
    ins_df = ins[ins.region==i]
    X=ins_df.drop(['charges', 'region'], axis=1)
    y=ins_df.charges
    
    # Add polynomial features
    pf = PolynomialFeatures(degree=2, include_bias=False)
    X_pf = pd.DataFrame(data=pf.fit_transform(X), columns=pf.get_feature_names_out(X.columns))
    
    # Create training and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_pf, y, test_size=0.2, random_state=1)
    X_train = pd.DataFrame(X_train, columns = X_pf.columns)
    X_test = pd.DataFrame(X_test, columns = X_pf.columns)
    actuals.append(pd.Series(y_test, name='actuals').reset_index())
    print("\nRegion: {}\n".format(i))
    print("Train Shape:{} {}  Test Shape:{} {}".format(X_train.shape, y_train.shape, X_test.shape, y_test.shape))
    
    # Scale features
    X_train = pd.DataFrame(data=s.fit_transform(X_train), columns=X_pf.columns)
    X_test = pd.DataFrame(data=s.transform(X_test), columns=X_pf.columns)
    
    # KNN
    grid = {'n_neighbors': range(2, 20),
            'weights': ['uniform', 'distance'],
            'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
            'leaf_size': [int(x) for x in np.linspace(10, 50, num = 5)],
            'p': [1, 2]}
    knn=KNeighborsRegressor()
    knn_cv=RandomizedSearchCV(estimator=knn, param_distributions=grid, scoring='neg_mean_squared_error', 
                              n_iter=100, cv=3, random_state=21, n_jobs=-1)
    knn_cv.fit(X_train, y_train)
    y_pred=knn_cv.predict(X_test)
    preds.append(pd.Series(y_pred, name='preds').reset_index(drop=True))
    rmse=np.sqrt(mean_squared_error(y_test, y_pred)).round(2)
    r2=r2_score(y_test, y_pred)
    adj_r2 = 1 - (1-r2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
    rmses.append(rmse)
    r2_scores.append(r2)
    adj_r2_scores.append(adj_r2)
    
    print("Test Error (RMSE) = {:,}".format(rmse))
    print("R-Squared = {:.2f}%, Adjusted R-Squared = {:.2f}%".format(r2*100, adj_r2*100))
    if i != 'Northeast':
        print("__________________________")

    
# Plot results
for i in range(0,4):
    actuals[i].loc[:,'index']=regions[i]
actual = pd.concat([actuals[i] for i in range(4)], axis = 0)
pred = pd.concat([preds[i] for i in range(4)], axis = 0)
df = pd.concat([actual, pred], axis=1).reset_index(drop=True)

fig = px.scatter(df, x="actuals", y="preds", color="index", trendline="lowess", height=700,
                 title="Actual vs Predicted Insurance Costs by Region,<br>K-Nearest Neighbors",
                 color_discrete_sequence=col, opacity=0.7, facet_col='index', facet_col_wrap=2)

fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[0]*100,rmses[0]),
                   x=51e3,y=15e3, row=2,col=1, showarrow=False)
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[1]*100,rmses[1]),
                   x=51e3,y=15e3, row=2,col=2, showarrow=False)
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[2]*100,rmses[2]),
                   x=51e3,y=15e3, row=1,col=1, showarrow=False)
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[3]*100,rmses[3]),
                   x=51e3,y=15e3, row=1,col=2, showarrow=False)

fig.update_traces(hovertemplate="Actual Cost: %{x:$,.2f}<br>Predicted Cost: %{y:$,.2f}",
                  marker=dict(size=10,line=dict(width=1,color="#F7F7F7")),
                  selector=dict(mode="markers"), showlegend=False)
fig.update_xaxes(title="Actual Cost, $", row=1)
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#EAEAEA',
                 zeroline=True, zerolinewidth=2, zerolinecolor='#5E5E5E')
fig.update_yaxes(title="Predicted Cost, $", col=1)
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#E3E3E3',
                 zeroline=True, zerolinewidth=2, zerolinecolor='#5E5E5E')
fig.update_layout(font_color="#303030", paper_bgcolor="white", plot_bgcolor="white")
fig.show()
# Out:
# Region: Southwest
#
# Train Shape:(260, 20) (260,)  Test Shape:(65, 20) (65,)
# Test Error (RMSE) = 5,227.12
# R-Squared = 80.09%, Adjusted R-Squared = 71.04%
# __________________________
#
# Region: Southeast
#
# Train Shape:(291, 20) (291,)  Test Shape:(73, 20) (73,)
# Test Error (RMSE) = 4,455.86
# R-Squared = 91.29%, Adjusted R-Squared = 87.95%
# __________________________
#
# Region: Northwest
#
# Train Shape:(260, 20) (260,)  Test Shape:(65, 20) (65,)
# Test Error (RMSE) = 6,179.18
# R-Squared = 75.45%, Adjusted R-Squared = 64.29%
# __________________________
#
# Region: Northeast
#
# Train Shape:(259, 20) (259,)  Test Shape:(65, 20) (65,)
# Test Error (RMSE) = 5,621.77
# R-Squared = 70.11%, Adjusted R-Squared = 56.52%
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="91785650-f7a4-4d66-8d9a-64cd15f936ef" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("91785650-f7a4-4d66-8d9a-64cd15f936ef")) {                    Plotly.newPlot(                        "91785650-f7a4-4d66-8d9a-64cd15f936ef",                        [{"hovertemplate":"Actual Cost: %{x:$,.2f}\u003cbr\u003ePredicted Cost: %{y:$,.2f}","legendgroup":"Southwest","marker":{"color":"#B14B51","opacity":0.7,"symbol":"circle","line":{"color":"#F7F7F7","width":1},"size":10},"mode":"markers","name":"Southwest","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"3SQGgZVirUA9CtejEM3GQMuhRbbzp7hAF9nO94P3y0DLoUW2c5DGQGq8dJMY2LNAg8DKoYUmwEBg5dAi29qsQOf7qfGu\u002fOFAEFg5tFjUyUC6SQwCo8LWQKG+ZU4EK+FAdZMYBJYdyECgGi\u002fdtKjDQI2XbhJDcLVAAAAAAODm4kCiRbbz3Ry8QAaBlUOLq7lAYOXQIrtbt0BzaJHtlAHhQNv5fmpcyLlAVOOlm5Bz40AEVg4tMqGTQNejcD0KaZNAYhBYOVSaskB1kxgEZhjCQEjhehRuT8pAMQisHFp9m0D2KFyPQmaTQDvfT42r
A=="},"xaxis":"x3","y":{"dtype":"f8","bdata":"YnYCezo4qEClXt3GfjmoQHXiZeoUU6hAzaSwsDZdqECJjWdwlcerQMofLV\u002fH5KtAmOAyMz5YrUCQUdQOK6atQFM9juKhtrRAQvF\u002fAuvytEClKOJCJry1QGc+leEvBbhA4cFcdfhhuEDTncJ2\u002fWu4QKdYcM4\u002fh7lAkgKyWQb1ukC865fQW7K8QLOpJt814b1AVjbtPSzGvkBFrNG7hN6+QPGvhPNutb9A6Uy12H1NwEAVSRv7u+TAQIbaEjKJxcFAKMg5BlfIwUCDm7p4Of\u002fBQKAy4jVGGMJA58LokXkjwkBqS5et ...

# %% [markdown]
# <b>6.1 | Model Summary</b>

# %%
mod_res.iloc[1,0]=pd.Series(rmses).mean()
mod_res.iloc[1,1]=pd.Series(adj_r2_scores).mean()
display(mod_res.iloc[:2,].sort_values("Average RMSE"))
# Out:
#                   Average RMSE Avg. Adjusted R2
# KNN                  5370.9825         0.699493
# Linear Regression      5646.52         0.741028

# %% [markdown]
# While KNN models generally yield lower test errors than linear regression, they account for less of the explained variance in insurance costs across all regions.

# %% [markdown]
# <b>7 | Support Vector Regression</b>

# %%
actuals=[]
preds=[]
rmses=[]
r2_scores=[]
adj_r2_scores=[]
feat_importance=pd.DataFrame()

for i in regions:
    
    print("\nRegion: {}\n".format(i))
    
    # Filter data by region
    ins_df = ins[ins.region==i]
    X=ins_df.drop(['charges', 'region'], axis=1)
    y=ins_df.charges
    
    # Add polynomial features
    pf = PolynomialFeatures(degree=2, include_bias=False)
    X_pf = pd.DataFrame(data=pf.fit_transform(X), columns=pf.get_feature_names_out(X.columns))
    
    # Create training and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_pf, y, test_size=0.2, random_state=1)
    X_train = pd.DataFrame(X_train, columns = X_pf.columns)
    X_test = pd.DataFrame(X_test, columns = X_pf.columns)
    actuals.append(pd.Series(y_test, name='actuals').reset_index())
    
    # Scale features
    X_train = pd.DataFrame(data=s.fit_transform(X_train), columns=X_pf.columns)
    X_test = pd.DataFrame(data=s.transform(X_test), columns=X_pf.columns)
    
    # Tuning SVM
    grid = {'kernel':['linear','rbf','poly','sigmoid'],
            'C': np.logspace(-3, 3, 10),
            'gamma':np.logspace(-3, 3, 10)}
    svm = SVR()
    svm_cv=RandomizedSearchCV(estimator=svm, param_distributions=grid, scoring='neg_mean_squared_error', 
                              n_iter=10, cv=3, random_state=21, n_jobs=-1)
    svm_cv.fit(X_train, y_train)
    print("Best SVM Parameters:\n",svm_cv.best_params_)
    y_pred=svm_cv.predict(X_test)
    preds.append(pd.Series(y_pred, name='preds').reset_index(drop=True))
    rmse=np.sqrt(mean_squared_error(y_test, y_pred)).round(2)
    r2=r2_score(y_test, y_pred)
    adj_r2 = 1 - (1-r2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
    rmses.append(rmse)
    r2_scores.append(r2)
    adj_r2_scores.append(adj_r2)
    
    print("\nTest Error (RMSE) = {:,}".format(rmse))
    print("R-Squared = {:.2f}%, Adjusted R-Squared = {:.2f}%".format(r2*100, adj_r2*100))
    if i != 'Northeast':
        print("__________________________")

    
# Plot results
for i in range(0,4):
    actuals[i].loc[:,'index']=regions[i]
actual = pd.concat([actuals[i] for i in range(4)], axis = 0)
pred = pd.concat([preds[i] for i in range(4)], axis = 0)
df = pd.concat([actual, pred], axis=1).reset_index(drop=True)

fig = px.scatter(df, x="actuals", y="preds", color="index", trendline="lowess", height=700,
                 title="Actual vs Predicted Insurance Costs by Region,<br>Support Vector Regression",
                 color_discrete_sequence=col, opacity=0.7, facet_col='index', facet_col_wrap=2)

fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[0]*100,rmses[0]),
                   x=51e3,y=15e3, row=2,col=1, showarrow=False)
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[1]*100,rmses[1]),
                   x=51e3,y=15e3, row=2,col=2, showarrow=False)
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[2]*100,rmses[2]),
                   x=51e3,y=15e3, row=1,col=1, showarrow=False)
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[3]*100,rmses[3]),
                   x=51e3,y=15e3, row=1,col=2, showarrow=False)

fig.update_traces(hovertemplate="Actual Cost: %{x:$,.2f}<br>Predicted Cost: %{y:$,.2f}",
                  marker=dict(size=10,line=dict(width=1,color="#F7F7F7")),
                  selector=dict(mode="markers"), showlegend=False)
fig.update_xaxes(title="Actual Cost, $", row=1)
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#EAEAEA',
                 zeroline=True, zerolinewidth=2, zerolinecolor='#5E5E5E')
fig.update_yaxes(title="Predicted Cost, $", col=1)
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#E3E3E3',
                 zeroline=True, zerolinewidth=2, zerolinecolor='#5E5E5E')
fig.update_layout(font_color="#303030", paper_bgcolor="white", plot_bgcolor="white")
fig.show()
# Out:
# Region: Southwest
#
# Best SVM Parameters:
#  {'kernel': 'poly', 'gamma': np.float64(10.0), 'C': np.float64(0.021544346900318832)}
#
# Test Error (RMSE) = 5,119.96
# R-Squared = 80.90%, Adjusted R-Squared = 72.21%
# __________________________
#
# Region: Southeast
#
# Best SVM Parameters:
#  {'kernel': 'poly', 'gamma': np.float64(10.0), 'C': np.float64(0.021544346900318832)}
#
# Test Error (RMSE) = 4,276.06
# R-Squared = 91.98%, Adjusted R-Squared = 88.90%
# __________________________
#
# Region: Northwest
#
# Best SVM Parameters:
#  {'kernel': 'poly', 'gamma': np.float64(10.0), 'C': np.float64(0.021544346900318832)}
#
# Test Error (RMSE) = 6,092.5
# R-Squared = 76.13%, Adjusted R-Squared = 65.28%
# __________________________
#
# Region: Northeast
#
# Best SVM Parameters:
#  {'kernel': 'poly', 'gamma': np.float64(10.0), 'C': np.float64(0.021544346900318832)}
#
# Test Error (RMSE) = 4,688.98
# R-Squared = 79.21%, Adjusted R-Squared = 69.75%
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="6d77cbda-9859-44c5-8cde-891d4d11b4b0" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6d77cbda-9859-44c5-8cde-891d4d11b4b0")) {                    Plotly.newPlot(                        "6d77cbda-9859-44c5-8cde-891d4d11b4b0",                        [{"hovertemplate":"Actual Cost: %{x:$,.2f}\u003cbr\u003ePredicted Cost: %{y:$,.2f}","legendgroup":"Southwest","marker":{"color":"#B14B51","opacity":0.7,"symbol":"circle","line":{"color":"#F7F7F7","width":1},"size":10},"mode":"markers","name":"Southwest","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":
ucdAdZMYBJYdyEAQWDm0WNTJQEjhehRuT8pAWDm0yGb\u002fykAX2c73g\u002ffLQPCnxks3Rs1A2\u002fl+amy0z0DsUbgeRa7QQFg5tMiGhdFA\u002fKnx0s3U0UCGIAclkiXUQLpJDAKjwtZA8KfGS1+32EAwuycPF4fZQHNoke2UAeFAob5lTgQr4UDn+6nxrvzhQESLbOfrGuJASgwCK+\u002fB4kAAAAAA4ObiQFTjpZuQc+NAQmDl0Brt5EA730+Nq4XnQA=="},"xaxis":"x3","y":{"dtype":"f8","bdata":"\u002fDG2wEDa1tBmeP\u002fAQH54K\u002fxIPMFAiUhk ...

# %% [markdown]
# <b>7.1 | Model Summary</b>

# %%
mod_res.iloc[2,0]=pd.Series(rmses).mean()
mod_res.iloc[2,1]=pd.Series(adj_r2_scores).mean()
display(mod_res.iloc[:3,].sort_values("Average RMSE"))
# Out:
#                   Average RMSE Avg. Adjusted R2
# SVM                   5044.375         0.740378
# KNN                  5370.9825         0.699493
# Linear Regression      5646.52         0.741028

# %% [markdown]
# Support Vector Regression (SVR) achieves the lowest average test error among the three models, with an adjusted  $R^2$ score of 74%. Utilizing a polynomial kernel, the SVR models consistently deliver lower test errors across all four regions. Notably, the Northeast model saw the most significant improvement, reducing its RMSE by nearly $1,000 compared to the KNN model.

# %% [markdown]
# <b>8 | Gradient Boosting</b>

# %%
actuals=[]
preds=[]
rmses=[]
r2_scores=[]
adj_r2_scores=[]
feat_importance=pd.DataFrame()

for i in regions:
    
    # Filter data by region
    ins_df = ins[ins.region==i]
    X=ins_df.drop(['charges', 'region'], axis=1)
    y=ins_df.charges
    
    # Add polynomial features
    pf = PolynomialFeatures(degree=2, include_bias=False)
    X_pf = pd.DataFrame(data=pf.fit_transform(X), columns=pf.get_feature_names_out(X.columns))
    
    # Create training and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_pf, y, test_size=0.2, random_state=1)
    X_train = pd.DataFrame(X_train, columns = X_pf.columns)
    X_test = pd.DataFrame(X_test, columns = X_pf.columns)
    actuals.append(pd.Series(y_test, name='actuals').reset_index())
    print("\nRegion: {}\n".format(i))
    print("Train Shape:{} {}  Test Shape:{} {}".format(X_train.shape, y_train.shape, X_test.shape, y_test.shape))
    
    # Scale features
    X_train = pd.DataFrame(data=s.fit_transform(X_train), columns=X_pf.columns)
    X_test = pd.DataFrame(data=s.transform(X_test), columns=X_pf.columns)
    
    # Tuning 
    grid = {'learning_rate': [0.0001, 0.001, 0.01, 0.1, 0.25, 0.5],
            'n_estimators': [int(x) for x in np.linspace(start = 200, stop = 1000, num = 5)],
            'subsample': [0.5, 0.8, 1],
            'min_samples_split': [2, 5, 10],
            'min_samples_leaf': [1, 2, 4],
            'max_depth': [int(x) for x in np.linspace(2, 10, num = 5)],
            'max_features': [None, 'sqrt']}
    xgb=GradientBoostingRegressor(random_state=21)
    xgb_cv=RandomizedSearchCV(estimator=xgb, param_distributions=grid, scoring='neg_mean_squared_error', 
                              n_iter=100, cv=3, random_state=21, n_jobs=-1)
    xgb_cv.fit(X_train, y_train)
    y_pred=xgb_cv.predict(X_test)
    preds.append(pd.Series(y_pred, name='preds').reset_index(drop=True))
    rmse=np.sqrt(mean_squared_error(y_test, y_pred)).round(2)
    r2=r2_score(y_test, y_pred)
    adj_r2 = 1 - (1-r2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
    rmses.append(rmse)
    r2_scores.append(r2)
    adj_r2_scores.append(adj_r2)
    
    # Save feature importance
    feat_importance["Importance_"+str(i)]=xgb_cv.best_estimator_.feature_importances_
    
    print("Test Error (RMSE) = {:,}".format(rmse))
    print("R-Squared = {:.2f}%, Adjusted R-Squared = {:.2f}%".format(r2*100, adj_r2*100))
    if i != 'Northeast':
        print("__________________________")

# Plot results
for i in range(0,4):
    actuals[i].loc[:,'index']=regions[i]
actual = pd.concat([actuals[i] for i in range(4)], axis = 0)
pred = pd.concat([preds[i] for i in range(4)], axis = 0)
df = pd.concat([actual, pred], axis=1).reset_index(drop=True)

fig = px.scatter(df, x="actuals", y="preds", color="index", trendline="lowess", height=700,
                 title="Actual vs Predicted Insurance Costs by Region,<br>Gradient Boosting",
                 color_discrete_sequence=col, opacity=0.7, facet_col='index', facet_col_wrap=2)

fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[0]*100,rmses[0]),
                   x=51e3,y=15e3, row=2,col=1, showarrow=False)
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[1]*100,rmses[1]),
                   x=51e3,y=15e3, row=2,col=2, showarrow=False)
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[2]*100,rmses[2]),
                   x=51e3,y=15e3, row=1,col=1, showarrow=False)
fig.add_annotation(text="Adj. R-Squared = {:.1f}%<br>RMSE = {:,.0f}".format(adj_r2_scores[3]*100,rmses[3]),
                   x=51e3,y=15e3, row=1,col=2, showarrow=False)

fig.update_traces(hovertemplate="Actual Cost: %{x:$,.2f}<br>Predicted Cost: %{y:$,.2f}",
                  marker=dict(size=10,line=dict(width=1,color="#F7F7F7")),
                  selector=dict(mode="markers"), showlegend=False)
fig.update_xaxes(title="Actual Cost, $", row=1)
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#EAEAEA',
                 zeroline=True, zerolinewidth=2, zerolinecolor='#5E5E5E')
fig.update_yaxes(title="Predicted Cost, $", col=1)
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#E3E3E3',
                 zeroline=True, zerolinewidth=2, zerolinecolor='#5E5E5E')
fig.update_layout(font_color="#303030", paper_bgcolor="white", plot_bgcolor="white")
fig.show()
# Out:
# Region: Southwest
#
# Train Shape:(260, 20) (260,)  Test Shape:(65, 20) (65,)
# Test Error (RMSE) = 4,117.69
# R-Squared = 87.64%, Adjusted R-Squared = 82.03%
# __________________________
#
# Region: Southeast
#
# Train Shape:(291, 20) (291,)  Test Shape:(73, 20) (73,)
# Test Error (RMSE) = 3,212.02
# R-Squared = 95.48%, Adjusted R-Squared = 93.74%
# __________________________
#
# Region: Northwest
#
# Train Shape:(260, 20) (260,)  Test Shape:(65, 20) (65,)
# Test Error (RMSE) = 4,559.91
# R-Squared = 86.63%, Adjusted R-Squared = 80.55%
# __________________________
#
# Region: Northeast
#
# Train Shape:(259, 20) (259,)  Test Shape:(65, 20) (65,)
# Test Error (RMSE) = 5,275.79
# R-Squared = 73.68%, Adjusted R-Squared = 61.71%
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="c453db07-6923-4984-ad8a-caa800d4ac9a" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c453db07-6923-4984-ad8a-caa800d4ac9a")) {                    Plotly.newPlot(                        "c453db07-6923-4984-ad8a-caa800d4ac9a",                        [{"hovertemplate":"Actual Cost: %{x:$,.2f}\u003cbr\u003ePredicted Cost: %{y:$,.2f}","legendgroup":"Southwest","marker":{"color":"#B14B51","opacity":0.7,"symbol":"circle","line":{"color":"#F7F7F7","width":1},"size":10},"mode":"markers","name":"Southwest","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":
%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Southwest","marker":{"color":"#B14B51","symbol":"circle"},"mode":"lines","name":"Southwest","showlegend":false,"x":{"dtype":"f8","bdata":"\u002fup8cIqwEAnMQisPH7AQPLSTWIApcBAvHSTGHS2wEB9PzVeuv\u002fAQLpJDAKLPMFAdZMYBGYYwkCgGi\u002fdtKjDQI\u002fC9Sh8uMNAFK5H4foTxUDI72369xXFQHE9Ctdjx8VAPQrXo2AxxkDhehSu10nGQMuhRbZzkMZAPQrXoxCcxkA9CtejEM3GQDVeukl8ucdAdZMYBJYdyEAQWDm0WNTJQEjhehRuT8pAWDm0yGb\u002fykAX2c73g\u002ffLQPCnxks3Rs1A2\u002fl+amy0z0DsUbgeRa7QQFg5tMiGhdFA\u002fKnx0s3U0UCGIAclkiXUQLpJDAKjwtZA8KfGS1+32EAwuycPF4fZQHNoke2UAeFAob5lTgQr4UDn+6nxrvzhQESLbOfrGuJASgwCK+\u002fB4kAAAAAA4ObiQFTjpZuQc+NAQmDl0Brt5EA730+Nq4XnQA=="},"xaxis":"x3","y":{"dtype":"f8","bdata":"vATkVeq7pEAUYRyIQb2kQD\u002f1Nv9V2KRAqoL0eQ\u002fjpEBlS42H94KoQMvGN1UGoqhAOpBwAJEtqkCPZ6GvoICqQCbrvgFYkLNAiXGhtj3Rs0BVRVQx7Km0QHyIik6fH7dAk8AtllWDt0BirDAHGY63QGKLX5D6vbhA0tnojehEukA+iSf5Oh68QCTgRz1BYb1A6FZmV\u002fJdvkD3uIrMw3m+QLfNgl5zeL9ABWK7vqlFwECoW91EZ\u002f3AQL0RZ0ntGsJAN6W0PL0ewkARLrQQGmrCQMfFXHBUjcJAewbCyjedwkCEMKDKDODCQP3Dw9iXF8NAv3vY ...

# %% [markdown]
# <b>8.1 | Overall Model Results</b>

# %%
mod_res.iloc[3,0]=pd.Series(rmses).mean()
mod_res.iloc[3,1]=pd.Series(adj_r2_scores).mean()
mod_res["Average RMSE"]=mod_res["Average RMSE"].map('{:,.2f}'.format)
mod_res["Avg. Adjusted R2"]=mod_res["Avg. Adjusted R2"].mul(100).map('{:.2f}%'.format)
display(mod_res.sort_values("Average RMSE"))
# Out:
#                   Average RMSE Avg. Adjusted R2
# Gradient Boosting     4,291.35           79.51%
# SVM                   5,044.38           74.04%
# KNN                   5,370.98           69.95%
# Linear Regression     5,646.52           74.10%

# %% [markdown]
# Gradient Boosting further reduced the overall test error to $4,291 and boosted the average adjusted $R^2$ to nearly 80%. While Gradient Boosting outperforms Support Vector Regression (SVR) in most regions, SVR still yields the lowest test error specifically in the Northeast.

# %% [markdown]
# <b>8.2| Feature Importance</b>

# %%
col=sns.color_palette("magma", 20).as_hex()[::-1]
feat_importance.set_index(X_train.columns, inplace=True)
ft=pd.DataFrame({"Average Importance":feat_importance.mean(axis=1)})
plot_df=ft.nlargest(20, columns="Average Importance").sort_values(by="Average Importance",ascending=False)
fig = px.bar(plot_df, x="Average Importance", y=plot_df.index, text="Average Importance", height=700,
             color=plot_df.index,width=700,opacity=.8,color_discrete_sequence=col)
fig.update_traces(texttemplate='%{text:.2f}', textposition='outside',
                  marker_line=dict(width=1, color='#3F3B3A'), showlegend=False, 
                  hovertemplate='Importance = <b>%{x:.2}</b>')
fig.update_layout(title_text='Feature Importance in Predicting Health Insurance Costs', 
                  coloraxis_showscale=False, yaxis_title="", font_color="#303030", yaxis_linecolor="#D8D8D8", 
                  xaxis=dict(title="Average Feature Importance", showgrid=True, showline=True, 
                             linecolor="#9A9A9A", gridcolor="#F5F5F5"))
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="e7dd52f8-0e47-40e5-bf54-8596201240e5" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e7dd52f8-0e47-40e5-bf54-8596201240e5")) {                    Plotly.newPlot(                        "e7dd52f8-0e47-40e5-bf54-8596201240e5",                        [{"hovertemplate":"Importance = \u003cb\u003e%{x:.2}\u003c\u002fb\u003e","legendgroup":"bmi smoker_yes","marker":{"color":"#fde7a9","opacity":0.8,"pattern":{"shape":""},"line":{"color":"#3F3B3A","width":1}},"name":"bmi smoker_yes","orientation":"h","showlegend":false,"text":{"dtype":"f8","bdata":"IKPnQVJwzj8="},"textposition":"outside","x":{"dtype":"f8","bdata":"IKPnQVJwzj8="},"xaxis":"x","y":["bmi smoker_yes"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}"},{"hovertemplate":"Importance = \u003cb\u003e%{x:.2}\u003c\u002fb\u003e","legendgroup":"age smoker_yes","marker":{"color":"#fed194","opacity":0.8,"pattern":{"shape":""},"line":{"color":"#3F3B3A","width":1}},"name":"age smoker_yes","orientation":"h","showlegend":false,"text":{"dtype":"f8","bdata":"I+aDyVL\u002fwz8="},"textposition":"outside","x":{"dtype":"f8","bdata":"I+aDyVL\u002fwz8="},"xaxis":"x","y":["age smoker_yes"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}"},{"hovertemplate":"Importance = \u003cb\u003e%{x:.2}\u003c\u002fb\u003e","legendgroup":"smoker_yes^2","marker":{"color":"#febb81","opacity":0.8,"pattern":{"shape":""},"line":{"color":"#3F3B3A","width":1}},"name":"smoker_yes^2","orientation":"h","showlegend":false,"text":{"dtype":"f8","bdata":"yRWTZu4Xwj8="},"textposition":"outside","x":{"dtype":"f8","bdata":"yRWTZu4Xwj8="},"xaxis":"x","y":["smoker_yes^2"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}"},{"hovertemplate":"Importance = \u003cb\u003e%{x:.2}\u003c\u002fb\u003e","legendgroup":"smoker_yes","marker":{"color":"#fea571","opacity":0.8,"pattern":{"shape":""},"line":{"color":"#3F3B3A","width":1}},"name":"smoker_yes","orientation":"h","showlegend":false,"text":{"dtype":"f8","bdata":"9btKLtU6wT8="},"textposition":"outside","x":{"dtype":"f8","bdata":"9btKLtU6wT8="},"xaxis":"x","y":["smoker_yes"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}"},{"hovertemplate":"Importance = \u003cb\u003e%{x:.2}\u003c\u002fb\u003e","legendgroup":"age bmi","marker":{"color":"#fc8e64","opacity":0.8,"pattern":{"shape":""},"line":{"color":"#3F3B3A","width":1}},"name":"age bmi","orientation":"h","showlegend":false,"text":{"dtype":"f8","bdata":"x45T2IJ4rD8="},"textposition":"outside","x":{"dtype":"f8","bdata":"x45T2IJ4rD8="},"xaxis":"x","y":["age bmi"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}"},{"hovertemplate":"Importance = \u003cb\u003e%{x:.2}\u003c\u002fb\u003e","legendgroup":"age","marker":{"color":"#f8765c","opacity":0.8,"pattern":{"shape":""},"line":{"color":"#3F3B3A","width":1}},"name":"age","orientation":"h","showlegend":false,"text":{"dtype":"f8","bdata":"zzXh794EqT8="},"textposition":"outside","x":{"dtype":"f8","bdata":"zzXh794EqT8="},"xaxis":"x","y":["age"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}"},{"hovertemplate":"Importance = \u003cb\u003e%{x:.2}\u003c\u002fb\u003e","legendgroup":"age^2","marker":{"color":"#f1605d","opacity":0.8,"pattern":{"shape":""},"line":{"color":"#3F3B3A","width":1}},"name":"age^2","orientation":"h","showlegend":false,"text":{"dtype":"f8","bdata":"biG1dAt4pj8="},"textposition":"outside","x":{"dtype":"f8","bdata":"biG1dAt4pj8="},"xaxis":"x","y":["age^2"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}"},{"hovertemplate":"Importance = \u003cb\u003e%{x:.2}\u003c\u002fb\u003e","legendgroup":"bmi^2","marker":{"color":"#e44f64","opacity":0.8,"pattern":{"shape":""},"line":{"color":"#3 ...

# %% [markdown]
# Analysis of average feature importances from the Gradient Boosting models indicates that the interaction between a patient's BMI and smoking status is the most crucial predictor of healthcare costs. Smoking status itself consistently shows the highest average importance, with interactions between age and BMI also ranking in the top five predictors. Polynomial features of age and BMI are present within the top ten, while gender and number of children are among the least influential.

# %% [markdown]
# <b>9 | Conclusion</b>
#
# For predicting insurance costs, Gradient Boosting delivers superior results in the Southwest, Southeast, and Northwest regions, while the Support Vector Machine (SVM) model achieves the lowest test error in the Northeast. Model performance in terms of explained variance ranges from over 93% in the Southeast to nearly 70% in the Northeast (with the SVM model).
#
# The added polynomial features and interaction effects, especially between smoking status and BMI, proved to be among the most crucial predictors of health insurance costs. Costs were also observed to increase with age and were significantly higher for smokers. Conversely, gender and the number of children had minimal influence on the models.
#
# Further improving the Northeast's Gradient Boosting model might involve additional hyperparameter tuning, or a hybrid modeling approach combining boosted trees and Support Vector Regression could be implemented for regional insurance claim predictions
